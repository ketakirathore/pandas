# %%
#pip install pandas

# %%
import pandas as pd

# %%
#1st process read data and then all the process will held

# %%
pd.read_csv(r"F:\car_data.csv")
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df = pd.read_csv(r"F:\car_data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#pandas have 2 data types = data frame and series

# %%
df = pd.read_excel(r"F:\Titanic.xlsx")
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df = pd.read_excel(r"F:\Titanic.xlsx",sheet_name = 'abc',header = None, names = ['sr.no', 'name'])
df
# Out:
#     sr.no                                               name
# 0       1                            Braund, Mr. Owen Harris
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3                             Heikkinen, Miss. Laina
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5                           Allen, Mr. William Henry
# 5       6                                   Moran, Mr. James
# 6       7                            McCarthy, Mr. Timothy J
# 7       8                     Palsson, Master. Gosta Leonard
# 8       9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9      10                Nasser, Mrs. Nicholas (Adele Achem)
# 10     11                    Sandstrom, Miss. Marguerite Rut
# 11     12                           Bonnell, Miss. Elizabeth

# %%
df = pd.read_excel(r"F:\Titanic.xlsx")
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.tail()
# Out:
#      PassengerId                                      Name  Pclass     Sex  \
# 886          887                     Montvila, Rev. Juozas       2    male
# 887          888              Graham, Miss. Margaret Edith       1  female
# 888          889  Johnston, Miss. Catherine Helen "Carrie"       3  female
# 889          890                     Behr, Mr. Karl Howell       1    male
# 890          891                       Dooley, Mr. Patrick       3    male
#
#       Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Survived
# 886  27.0      0      0      211536  13.00   NaN        S         0
# 887  19.0      0      0      112053  30.00   B42        S         1
# 888   NaN      1      2  W./C. 6607  23.45   NaN        S         0
# 889  26.0      0      0      111369  30.00  C148        C         1
# 890  32.0      0      0      370376   7.75   NaN        Q         0

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
#csv = comma separated value

# %%
df.columns
# Out:
# Index(['PassengerId', 'Name', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
#string = object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Name            object
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Survived         int64
# dtype: object

# %%
#this method is used because to perform operation on data need to identify datatypes to apply data types method on perticular
#deta type

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
type(df[['Name','Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
#std = standard deviation
#descibe method gives the statistical value it always works in numerical value

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Name            True
# Pclass         False
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# Survived       False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'float']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
df.dtypes[df.dtypes == 'int64']
# Out:
# PassengerId    int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# Survived       int64
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df[df.dtypes[df.dtypes == 'float'].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
#slicing

# %%
df1 = pd.read_csv(r"F:\car_data.csv")
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1['Year'][1:10:2]
# Out:
# 1    2013
# 3    2011
# 5    2018
# 7    2015
# 9    2015
# Name: Year, dtype: int64

# %%
df1[1:10:2]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 1      Dealer       Manual      0
# 3      Dealer       Manual      0
# 5      Dealer       Manual      0
# 7      Dealer       Manual      0
# 9      Dealer       Manual      0

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1['Year'] == 2025
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Name: Year, Length: 301, dtype: bool

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1['Cureent_year'] = 2025

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Cureent_year
# 0        Dealer       Manual      0          2025
# ...

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.isnull()
# Out:
#      PassengerId   Name  Pclass    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False  False   False  False  False  False  False   False  False
# 1          False  False   False  False  False  False  False   False  False
# 2          False  False   False  False  False  False  False   False  False
# 3          False  False   False  False  False  False  False   False  False
# 4          False  False   False  False  False  False  False   False  False
# ..           ...    ...     ...    ...    ...    ...    ...     ...    ...
# 886        False  False   False  False  False  False  False   False  False
# 887        False  False   False  False  False  False  False   False  False
# 888        False  False   False  False   True  False  False   False  False
# 889        False  False   False  False  False  False  False   False  False
# 890        False  False   False  False  False  False  False   False  False
#
#      Cabin  Embarked  Survived
# 0     True     False     False
# ...

# %%
df['Cabin'].isnull().sum()
# Out:
# np.int64(687)

# %%
#to find null value is necessary to check cause there shoudnt be a null value in the data. sum() check all the null value
#isnull() check null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
a = df.dropna()
a
# Out:
#      PassengerId                                               Name  Pclass  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 6              7                            McCarthy, Mr. Timothy J       1
# 10            11                    Sandstrom, Miss. Marguerite Rut       3
# 11            12                           Bonnell, Miss. Elizabeth       1
# ..           ...                                                ...     ...
# 871          872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1
# 872          873                           Carlsson, Mr. Frans Olof       1
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1
# 887          888                       Graham, Miss. Margaret Edith       1
# 889          890                              Behr, Mr. Karl Howell       1
#
# ...

# %%
a.isnull().sum()
# Out:
# PassengerId    0
# Name           0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Survived       0
# dtype: int64

# %%
a = df.dropna(axis=1)

# %%
a
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
a.isnull().sum()
# Out:
# PassengerId    0
# Name           0
# Pclass         0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Survived       0
# dtype: int64

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Cureent_year
# 0      Dealer       Manual      0          2025
# 1      Dealer       Manual      0          2025
# 2      Dealer       Manual      0          2025
# 3      Dealer       Manual      0          2025
# 4      Dealer       Manual      0          2025

# %%
df1[df1['Kms_Driven'] == max(df1['Kms_Driven'])]
# Out:
#       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 196  Activa 3g  2008           0.17           0.52      500000    Petrol
#
#     Seller_Type Transmission  Owner  Cureent_year
# 196  Individual    Automatic      0          2025

# %%
df1[df1['Kms_Driven'] == max(df1['Kms_Driven'])]['Car_Name']
# Out:
# 196    Activa 3g
# Name: Car_Name, dtype: object

# %%
df1[df1['Kms_Driven'] == max(df1['Kms_Driven'])]['Year']
# Out:
# 196    2008
# Name: Year, dtype: int64

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Cureent_year
# 0      Dealer       Manual      0          2025
# 1      Dealer       Manual      0          2025
# 2      Dealer       Manual      0          2025
# 3      Dealer       Manual      0          2025
# 4      Dealer       Manual      0          2025

# %%
df1[df1['Year']==2014]
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                    ritz  2014           3.35          5.590       27000
# 4                   swift  2014           4.60          6.870       42450
# 23               alto k10  2014           2.50          3.460       45280
# 32                  swift  2014           4.95          7.490       39000
# 33                 ertiga  2014           6.00          9.950       45000
# 34                  dzire  2014           5.50          8.060       45000
# 41               alto k10  2014           2.55          3.980       46706
# 43                  dzire  2014           5.50          8.060       45780
# 45                   ciaz  2014           7.50         12.040       15000
# 58                etios g  2014           4.10          6.800       39485
# 59               fortuner  2014          19.99         35.960       41000
# 62               fortuner  2014          18.75         35.960       78000
# ...

# %%
len(df1[df1['Year']==2014])
# Out:
# 38

# %%
df1[(df1['Year'] > 2014) & (df1['Kms_Driven'] < 7000)]
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 2                         ciaz  2017           7.25           9.85
# 5                vitara brezza  2018           9.25           9.83
# 10                    alto 800  2017           2.85           3.60
# 21                       ignis  2017           4.90           5.71
# 64                    fortuner  2017          33.00          36.23
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# 110                  KTM RC200  2016           1.20           1.78
# 120         Bajaj Pulsar RS200  2016           1.05           1.26
# 122   Royal Enfield Bullet 350  2016           1.05           1.17
# ...

# %%
df1[(df1['Year'] > 2014) | (df1['Kms_Driven'] < 7000)]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 3          wagon r  2011           2.85           4.15        5200    Petrol
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             ciaz  2015           6.75           8.12       18796    Petrol
# 7          s cross  2015           6.50           8.61       33429    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
# ...

# %%
df1['Car_age'] = df1['Cureent_year'] - df1['Year']

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Cureent_year  Car_age
# 0      Dealer       Manual      0          2025       11
# 1      Dealer       Manual      0          2025       12
# 2      Dealer       Manual      0          2025        8
# 3      Dealer       Manual      0          2025       14
# 4      Dealer       Manual      0          2025       11

# %%
df1.drop('Cureent_year', axis =1, inplace = True )
#df1 = df1.drop('Cureent_year', axis =1)

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_age
# 0      Dealer       Manual      0       11
# 1      Dealer       Manual      0       12
# 2      Dealer       Manual      0        8
# 3      Dealer       Manual      0       14
# 4      Dealer       Manual      0       11

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Car_age
# 0        Dealer       Manual      0       11
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
#  9   Car_age        301 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 23.6+ KB

# %%
df2 = pd.read_csv("F:\daily_total_births.csv")

# %%
df2
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    object
#  1   Births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
df2.describe()
# Out:
#            Births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
df2.isnull().sum()
# Out:
# Date      0
# Births    0
# dtype: int64

# %%
df2.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
date = pd.to_datetime(df2['Date'])

# %%
date
# Out:
# 0     1959-01-01
# 1     1959-01-02
# 2     1959-01-03
# 3     1959-01-04
# 4     1959-01-05
#          ...
# 360   1959-12-27
# 361   1959-12-28
# 362   1959-12-29
# 363   1959-12-30
# 364   1959-12-31
# Name: Date, Length: 365, dtype: datetime64[ns]

# %%
type(date)
# Out:
# pandas.core.series.Series

# %%
df2['converted_date'] = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#            Date  Births converted_date
# 0    1959-01-01      35     1959-01-01
# 1    1959-01-02      32     1959-01-02
# 2    1959-01-03      30     1959-01-03
# 3    1959-01-04      31     1959-01-04
# 4    1959-01-05      44     1959-01-05
# ..          ...     ...            ...
# 360  1959-12-27      37     1959-12-27
# 361  1959-12-28      52     1959-12-28
# 362  1959-12-29      48     1959-12-29
# 363  1959-12-30      55     1959-12-30
# 364  1959-12-31      50     1959-12-31
#
# [365 rows x 3 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            365 non-null    object
#  1   Births          365 non-null    int64
#  2   converted_date  365 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
df2.head()
# Out:
#          Date  Births converted_date
# 0  1959-01-01      35     1959-01-01
# 1  1959-01-02      32     1959-01-02
# 2  1959-01-03      30     1959-01-03
# 3  1959-01-04      31     1959-01-04
# 4  1959-01-05      44     1959-01-05

# %%
df2['Year'] = df2['converted_date'].dt.year

# %%
df2.head()
# Out:
#          Date  Births converted_date  Year
# 0  1959-01-01      35     1959-01-01  1959
# 1  1959-01-02      32     1959-01-02  1959
# 2  1959-01-03      30     1959-01-03  1959
# 3  1959-01-04      31     1959-01-04  1959
# 4  1959-01-05      44     1959-01-05  1959

# %%
df2['month'] = df2['converted_date'].dt.month

# %%
df2.head()
# Out:
#          Date  Births converted_date  Year  month
# 0  1959-01-01      35     1959-01-01  1959      1
# 1  1959-01-02      32     1959-01-02  1959      1
# 2  1959-01-03      30     1959-01-03  1959      1
# 3  1959-01-04      31     1959-01-04  1959      1
# 4  1959-01-05      44     1959-01-05  1959      1

# %%
df2['date'] = df2['converted_date'].dt.day

# %%
df2
# Out:
#            Date  Births converted_date  Year  month  date
# 0    1959-01-01      35     1959-01-01  1959      1     1
# 1    1959-01-02      32     1959-01-02  1959      1     2
# 2    1959-01-03      30     1959-01-03  1959      1     3
# 3    1959-01-04      31     1959-01-04  1959      1     4
# 4    1959-01-05      44     1959-01-05  1959      1     5
# ..          ...     ...            ...   ...    ...   ...
# 360  1959-12-27      37     1959-12-27  1959     12    27
# 361  1959-12-28      52     1959-12-28  1959     12    28
# 362  1959-12-29      48     1959-12-29  1959     12    29
# 363  1959-12-30      55     1959-12-30  1959     12    30
# 364  1959-12-31      50     1959-12-31  1959     12    31
#
# [365 rows x 6 columns]

# %%
df2['week'] = df2['converted_date'].dt.isocalendar().week

# %%
df2
# Out:
#            Date  Births converted_date  Year  month  date  week
# 0    1959-01-01      35     1959-01-01  1959      1     1     1
# 1    1959-01-02      32     1959-01-02  1959      1     2     1
# 2    1959-01-03      30     1959-01-03  1959      1     3     1
# 3    1959-01-04      31     1959-01-04  1959      1     4     1
# 4    1959-01-05      44     1959-01-05  1959      1     5     2
# ..          ...     ...            ...   ...    ...   ...   ...
# 360  1959-12-27      37     1959-12-27  1959     12    27    52
# 361  1959-12-28      52     1959-12-28  1959     12    28    53
# 362  1959-12-29      48     1959-12-29  1959     12    29    53
# 363  1959-12-30      55     1959-12-30  1959     12    30    53
# 364  1959-12-31      50     1959-12-31  1959     12    31    53
#
# [365 rows x 7 columns]

# %%
df2['month'].value_counts()
# Out:
# month
# 1     31
# 3     31
# 5     31
# 7     31
# 8     31
# 10    31
# 12    31
# 4     30
# 6     30
# 9     30
# 11    30
# 2     28
# Name: count, dtype: int64

# %%
df2.drop('date',axis = 1)
# Out:
#            Date  Births converted_date  Year  month  week
# 0    1959-01-01      35     1959-01-01  1959      1     1
# 1    1959-01-02      32     1959-01-02  1959      1     1
# 2    1959-01-03      30     1959-01-03  1959      1     1
# 3    1959-01-04      31     1959-01-04  1959      1     1
# 4    1959-01-05      44     1959-01-05  1959      1     2
# ..          ...     ...            ...   ...    ...   ...
# 360  1959-12-27      37     1959-12-27  1959     12    52
# 361  1959-12-28      52     1959-12-28  1959     12    53
# 362  1959-12-29      48     1959-12-29  1959     12    53
# 363  1959-12-30      55     1959-12-30  1959     12    53
# 364  1959-12-31      50     1959-12-31  1959     12    53
#
# [365 rows x 6 columns]

# %%
df2.drop(1)
# Out:
#            Date  Births converted_date  Year  month  date  week
# 0    1959-01-01      35     1959-01-01  1959      1     1     1
# 2    1959-01-03      30     1959-01-03  1959      1     3     1
# 3    1959-01-04      31     1959-01-04  1959      1     4     1
# 4    1959-01-05      44     1959-01-05  1959      1     5     2
# 5    1959-01-06      29     1959-01-06  1959      1     6     2
# ..          ...     ...            ...   ...    ...   ...   ...
# 360  1959-12-27      37     1959-12-27  1959     12    27    52
# 361  1959-12-28      52     1959-12-28  1959     12    28    53
# 362  1959-12-29      48     1959-12-29  1959     12    29    53
# 363  1959-12-30      55     1959-12-30  1959     12    30    53
# 364  1959-12-31      50     1959-12-31  1959     12    31    53
#
# [364 rows x 7 columns]

# %%
#loc= location and iloc

# %%
df2.loc[[2]]
# Out:
#          Date  Births converted_date  Year  month  date  week
# 2  1959-01-03      30     1959-01-03  1959      1     3     1

# %%
df2.loc[2:10]
# Out:
#           Date  Births converted_date  Year  month  date  week
# 2   1959-01-03      30     1959-01-03  1959      1     3     1
# 3   1959-01-04      31     1959-01-04  1959      1     4     1
# 4   1959-01-05      44     1959-01-05  1959      1     5     2
# 5   1959-01-06      29     1959-01-06  1959      1     6     2
# 6   1959-01-07      45     1959-01-07  1959      1     7     2
# 7   1959-01-08      43     1959-01-08  1959      1     8     2
# 8   1959-01-09      38     1959-01-09  1959      1     9     2
# 9   1959-01-10      27     1959-01-10  1959      1    10     2
# 10  1959-01-11      38     1959-01-11  1959      1    11     2

# %%
df2.loc[2:10, ['Date' , 'Births']]
# Out:
#           Date  Births
# 2   1959-01-03      30
# 3   1959-01-04      31
# 4   1959-01-05      44
# 5   1959-01-06      29
# 6   1959-01-07      45
# 7   1959-01-08      43
# 8   1959-01-09      38
# 9   1959-01-10      27
# 10  1959-01-11      38

# %%
df2.iloc[2:10, 0:3]
# Out:
#          Date  Births converted_date
# 2  1959-01-03      30     1959-01-03
# 3  1959-01-04      31     1959-01-04
# 4  1959-01-05      44     1959-01-05
# 5  1959-01-06      29     1959-01-06
# 6  1959-01-07      45     1959-01-07
# 7  1959-01-08      43     1959-01-08
# 8  1959-01-09      38     1959-01-09
# 9  1959-01-10      27     1959-01-10

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
df.fillna(value=21)
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df['Age'].fillna(value=df['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
data = {
    'name' : ['abc','def','ghi','hij'],
    'salary' : [100,200,300,400],
    'mail.id' :['abc@gmail.com','def@gmail.com','ghi@gmail.com','hij@gmail.com'],
    'addr' : ['mum','pune','delhi', 'mum']
}

# %%
data
# Out:
# {'name': ['abc', 'def', 'ghi', 'hij'],
#  'salary': [100, 200, 300, 400],
#  'mail.id': ['abc@gmail.com',
#   'def@gmail.com',
#   'ghi@gmail.com',
#   'hij@gmail.com'],
#  'addr': ['mum', 'pune', 'delhi', 'mum']}

# %%
pd.DataFrame(data)
# Out:
#   name  salary        mail.id   addr
# 0  abc     100  abc@gmail.com    mum
# 1  def     200  def@gmail.com   pune
# 2  ghi     300  ghi@gmail.com  delhi
# 3  hij     400  hij@gmail.com    mum

# %%
 pd.DataFrame(data,index=[4,5,6,7])
# Out:
#   name  salary        mail.id   addr
# 4  abc     100  abc@gmail.com    mum
# 5  def     200  def@gmail.com   pune
# 6  ghi     300  ghi@gmail.com  delhi
# 7  hij     400  hij@gmail.com    mum

# %%
df=  pd.DataFrame(data)
df
# Out:
#   name  salary        mail.id   addr
# 0  abc     100  abc@gmail.com    mum
# 1  def     200  def@gmail.com   pune
# 2  ghi     300  ghi@gmail.com  delhi
# 3  hij     400  hij@gmail.com    mum

# %%
data1 = {
    'pf_num' : [234,567,456,678],
    'income_tax' : [4545,655,342,3234],
    'mobile_num' : [23243,123342,34534,23423],
    'course' : ['DS', 'DA', 'PFS','FS']
}

# %%
df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#    pf_num  income_tax  mobile_num course
# 0     234        4545       23243     DS
# 1     567         655      123342     DA
# 2     456         342       34534    PFS
# 3     678        3234       23423     FS

# %%
pd.concat([df,df1], axis = 1)
# Out:
#   name  salary        mail.id   addr  pf_num  income_tax  mobile_num course
# 0  abc     100  abc@gmail.com    mum     234        4545       23243     DS
# 1  def     200  def@gmail.com   pune     567         655      123342     DA
# 2  ghi     300  ghi@gmail.com  delhi     456         342       34534    PFS
# 3  hij     400  hij@gmail.com    mum     678        3234       23423     FS

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
data2 = {'0' : ['abc','bcd','efg','hij'],
         '1' : [100,200,300,400],
         '2' : ['abc@gmail.com','bcd@gmail.com','efg@gmail.com','hij@gmail.com'],
         '3' : [ 'mumbai','pune','mumbai','banglore']
        }         
data3 = {'0' : [234,45,54465,656],
         '1' : [234,565,767,6778],
         '2' : [23453,45678,45546,434546],
         '3' : [ 'ds','bigdata','python','web']
        }

# %%
data2
# Out:
# {'0': ['abc', 'bcd', 'efg', 'hij'],
#  '1': [100, 200, 300, 400],
#  '2': ['abc@gmail.com', 'bcd@gmail.com', 'efg@gmail.com', 'hij@gmail.com'],
#  '3': ['mumbai', 'pune', 'mumbai', 'banglore']}

# %%
data3
# Out:
# {'0': [234, 45, 54465, 656],
#  '1': [234, 565, 767, 6778],
#  '2': [23453, 45678, 45546, 434546],
#  '3': ['ds', 'bigdata', 'python', 'web']}

# %%
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)

# %%
df2
# Out:
#      0    1              2         3
# 0  abc  100  abc@gmail.com    mumbai
# 1  bcd  200  bcd@gmail.com      pune
# 2  efg  300  efg@gmail.com    mumbai
# 3  hij  400  hij@gmail.com  banglore

# %%
df3
# Out:
#        0     1       2        3
# 0    234   234   23453       ds
# 1     45   565   45678  bigdata
# 2  54465   767   45546   python
# 3    656  6778  434546      web

# %%
pd.concat([df2,df3], axis=1)
# Out:
#      0    1              2         3      0     1       2        3
# 0  abc  100  abc@gmail.com    mumbai    234   234   23453       ds
# 1  bcd  200  bcd@gmail.com      pune     45   565   45678  bigdata
# 2  efg  300  efg@gmail.com    mumbai  54465   767   45546   python
# 3  hij  400  hij@gmail.com  banglore    656  6778  434546      web

# %%
data4 ={'emp_id' : [101,102,103,104],
        'salary' : [234,345,200,400],
        'pf' : [23,34,56,78]
       }
data5 = {'emp_id' : [101,102,103,104],
         'mobile_no' : [3434,5656,757,678],
         'house_no' : [345,345,345,345]
        }

# %%
df4 = pd.DataFrame(data4)
df5 = pd.DataFrame(data5)

# %%
df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df5
# Out:
#    emp_id  mobile_no  house_no
# 0     101       3434       345
# 1     102       5656       345
# 2     103        757       345
# 3     104        678       345

# %%
pd.merge(df4,df5)
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        757       345
# 3     104     400  78        678       345

# %%
pd.merge(df4,df5, how = 'left')
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        757       345
# 3     104     400  78        678       345

# %%
pd.merge(df4,df5, how = 'right', on = "emp_id")
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        757       345
# 3     104     400  78        678       345

# %%
#on = should be common column

# %%
data5 ={'emp_id1' : [101,102,103,104],
        'salary1' : [234,345,200,400],
        'pf1' : [23,34,56,78]
       }
data6 = {'emp_id2' : [101,102,103,104],
         'mobile_no2' : [3434,5656,757,678],
         'house_no2' : [345,345,345,345]
        }

# %%
df6 = pd.DataFrame(data5)
df7 = pd.DataFrame(data6)

# %%
df6
# Out:
#    emp_id1  salary1  pf1
# 0      101      234   23
# 1      102      345   34
# 2      103      200   56
# 3      104      400   78

# %%
df7
# Out:
#    emp_id2  mobile_no2  house_no2
# 0      101        3434        345
# 1      102        5656        345
# 2      103         757        345
# 3      104         678        345

# %%
pd.merge(df6,df7, left_on = 'emp_id1', right_on = 'emp_id2')
# Out:
#    emp_id1  salary1  pf1  emp_id2  mobile_no2  house_no2
# 0      101      234   23      101        3434        345
# 1      102      345   34      102        5656        345
# 2      103      200   56      103         757        345
# 3      104      400   78      104         678        345

# %%
data8 ={'emp_id' : [101,102,103,104],
        'salary' : [234,345,200,400],
        'pf' : [23,34,56,78]
       }
data9 = {'emp_id' : [101,102,103,105, 123],
         'mobile_no' : [3434,5656,757,678,454],
         'house_no' : [345,345,345,345,4534]
        }

# %%
df8 = pd.DataFrame(data8)
df9 = pd.DataFrame(data9)

# %%
df8
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df9
# Out:
#    emp_id  mobile_no  house_no
# 0     101       3434       345
# 1     102       5656       345
# 2     103        757       345
# 3     105        678       345
# 4     123        454      4534

# %%
pd.merge(df8, df9, on = ['emp_id'])
# Out:
#    emp_id  salary  pf  mobile_no  house_no
# 0     101     234  23       3434       345
# 1     102     345  34       5656       345
# 2     103     200  56        757       345

# %%
data10 ={'emp_id1' : [101,102,103,104],
        'salary1' : [234,345,200,400],
        'pf1' : [23,34,56,78]
       }
data11 = {'emp_id2' : [101,102,103,105, 123],
         'mobile_no2' : [3434,5656,757,678,454],
         'house_no3' : [345,345,345,345,4534]
        }

# %%
df10 = pd.DataFrame(data10, index = ['a','b','c','d'])
df11 = pd.DataFrame(data11, index = ['a', 'b', 'd','e', 'f'])

# %%
df10
# Out:
#    emp_id1  salary1  pf1
# a      101      234   23
# b      102      345   34
# c      103      200   56
# d      104      400   78

# %%
df11
# Out:
#    emp_id2  mobile_no2  house_no3
# a      101        3434        345
# b      102        5656        345
# d      103         757        345
# e      105         678        345
# f      123         454       4534

# %%
df10.join(df11)
# Out:
#    emp_id1  salary1  pf1  emp_id2  mobile_no2  house_no3
# a      101      234   23    101.0      3434.0      345.0
# b      102      345   34    102.0      5656.0      345.0
# c      103      200   56      NaN         NaN        NaN
# d      104      400   78    103.0       757.0      345.0

# %%
df11.join(df10)
# Out:
#    emp_id2  mobile_no2  house_no3  emp_id1  salary1   pf1
# a      101        3434        345    101.0    234.0  23.0
# b      102        5656        345    102.0    345.0  34.0
# d      103         757        345    104.0    400.0  78.0
# e      105         678        345      NaN      NaN   NaN
# f      123         454       4534      NaN      NaN   NaN

# %%
df1 = pd.read_csv(r"F:\car_data.csv")
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1[df1['Present_Price'] < 5]
# Out:
#      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 3     wagon r  2011           2.85           4.15        5200    Petrol
# 10   alto 800  2017           2.85           3.60        2135    Petrol
# 20   alto k10  2016           2.85           3.95       25000    Petrol
# 23   alto k10  2014           2.50           3.46       45280    Petrol
# 24    wagon r  2013           2.90           4.41       56879    Petrol
# ..        ...   ...            ...            ...         ...       ...
# 225       i10  2011           2.70           4.60       22517    Petrol
# 227       i10  2011           2.55           4.43       57000    Petrol
# 236       eon  2016           3.10           4.43       11849    Petrol
# 239       eon  2012           2.00           4.43       23709    Petrol
# 248       i10  2013           4.00           4.60       30000    Petrol
#
#     Seller_Type Transmission  Owner
# 3        Dealer       Manual      0
# ...

# %%
def review(x) :
    if x > 5 :
        return "High"
    else :
        return "low"

# %%
review (5.6)
# Out:
# 'High'

# %%
review(4.6)
# Out:
# 'low'

# %%
df1['review'] = df1['Present_Price'].apply(review)

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner review
# 0      Dealer       Manual      0   High
# 1      Dealer       Manual      0   High
# 2      Dealer       Manual      0   High
# 3      Dealer       Manual      0    low
# 4      Dealer       Manual      0   High

# %%
for i in df1.columns :
    print(df[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Car_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[153], line 2
#       1 for i in df1.columns :
# ----> 2     print(df[i])
#
# ...

# %%
df = pd.read_excel(r"F:\Titanic.xlsx")
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(df['Embarked'])
# Out:
# ['S', 'C', 'S', 'S', 'S', ..., 'S', 'S', 'S', 'C', 'Q']
# Length: 891
# Categories (3, object): ['C', 'Q', 'S']

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.sample(5)
# Out:
#      PassengerId                                               Name  Pclass  \
# 394          395  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...       3
# 261          262                  Asplund, Master. Edvin Rojj Felix       3
# 680          681                                Peters, Miss. Katie       3
# 835          836                        Compton, Miss. Sara Rebecca       1
# 15            16                    Hewlett, Mrs. (Mary D Kingcome)       2
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Survived
# 394  female  24.0      0      2   PP 9549  16.7000    G6        S         1
# 261    male   3.0      4      2    347077  31.3875   NaN        S         1
# 680  female   NaN      0      0    330935   8.1375   NaN        Q         0
# 835  female  39.0      1      1  PC 17756  83.1583   E49        C         1
# 15   female  55.0      0      0    248706  16.0000   NaN        S         1

# %%
df.sample(5)
# Out:
#      PassengerId                               Name  Pclass     Sex   Age  \
# 510          511           Daly, Mr. Eugene Patrick       3    male  29.0
# 716          717      Endres, Miss. Caroline Louise       1  female  38.0
# 382          383                 Tikkanen, Mr. Juho       3    male  32.0
# 546          547  Beane, Mrs. Edward (Ethel Clarke)       2  female  19.0
# 836          837                   Pasic, Mr. Jakob       3    male  21.0
#
#      SibSp  Parch             Ticket      Fare Cabin Embarked  Survived
# 510      0      0             382651    7.7500   NaN        Q         1
# 716      0      0           PC 17757  227.5250   C45        C         1
# 382      0      0  STON/O 2. 3101293    7.9250   NaN        S         0
# 546      1      0               2908   26.0000   NaN        S         1
# 836      0      0             315097    8.6625   NaN        S         0

# %%
l = ["Python", "web", "html","css","js"]

# %%
pd.DataFrame(l)
# Out:
#         0
# 0  Python
# 1     web
# 2    html
# 3     css
# 4      js

# %%
l = ["Python", "web", "html","css","js"]

# %%
df1 = pd.Series(l)

# %%
df1
# Out:
# 0    Python
# 1       web
# 2      html
# 3       css
# 4        js
# dtype: object

# %%
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner review
# 0        Dealer       Manual      0   High
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(2)

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner review
# 0      Dealer       Manual      0   High
# 1      Dealer       Manual      0   High
# 2      Dealer       Manual      0   High
# 3      Dealer       Manual      0    low
# 4      Dealer       Manual      0   High

# %%
df1['Year'].replace(2014,2025)
# Out:
# 0      2025
# 1      2013
# 2      2017
# 3      2011
# 4      2025
#        ...
# 296    2016
# 297    2015
# 298    2009
# 299    2017
# 300    2016
# Name: Year, Length: 299, dtype: int64

# %%
array = df1.to_numpy()

# %%
array
# Out:
# array([['ritz', 2014, 3.35, ..., 'Manual', 0, 'High'],
#        ['sx4', 2013, 4.75, ..., 'Manual', 0, 'High'],
#        ['ciaz', 2017, 7.25, ..., 'Manual', 0, 'High'],
#        ...,
#        ['city', 2009, 3.35, ..., 'Manual', 0, 'High'],
#        ['city', 2017, 11.5, ..., 'Manual', 0, 'High'],
#        ['brio', 2016, 5.3, ..., 'Manual', 0, 'High']], dtype=object)

# %%
type(array)
# Out:
# numpy.ndarray

# %%
df = pd.DataFrame(array, columns=['car_name','a','b','c','d','e','f','g','h','i'])

# %%
df
# Out:
#     car_name     a     b     c      d       e       f       g  h     i
# 0       ritz  2014  3.35  5.59  27000  Petrol  Dealer  Manual  0  High
# 1        sx4  2013  4.75  9.54  43000  Diesel  Dealer  Manual  0  High
# 2       ciaz  2017  7.25  9.85   6900  Petrol  Dealer  Manual  0  High
# 3    wagon r  2011  2.85  4.15   5200  Petrol  Dealer  Manual  0   low
# 4      swift  2014   4.6  6.87  42450  Diesel  Dealer  Manual  0  High
# ..       ...   ...   ...   ...    ...     ...     ...     ... ..   ...
# 294     city  2016   9.5  11.6  33988  Diesel  Dealer  Manual  0  High
# 295     brio  2015   4.0   5.9  60000  Petrol  Dealer  Manual  0  High
# 296     city  2009  3.35  11.0  87934  Petrol  Dealer  Manual  0  High
# 297     city  2017  11.5  12.5   9000  Diesel  Dealer  Manual  0  High
# 298     brio  2016   5.3   5.9   5464  Petrol  Dealer  Manual  0  High
#
# [299 rows x 10 columns]
